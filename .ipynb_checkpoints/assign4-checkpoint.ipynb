# %%
import os
import sys
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from scipy import integrate

# %%
pi = np.pi
e = np.e

# %%
def f(x):
    return np.exp(x)

# %%
def g(x):
    return np.cos(np.cos(x))

# %%
x = np.linspace(-2*pi,4*pi,100)
plt.grid()
plt.plot(x,g(x))
plt.title('Plot of g(x)')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.show()

# %%
plt.grid()
plt.semilogy(x,f(x))
plt.title('Plot of g(x) in semilog scale')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.show()

# %%
plt.grid()
plt.plot(x,f(x))
plt.title('Plot of g(x)')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.show()

# %%
def u(x,k):
    return f(x)*np.cos(k*x)
def v(x,k):
    return f(x)*np.sin(k*x)
def w(x,k):
    return g(x)*np.cos(k*x)
def z(x,k):
    return g(x)*np.sin(k*x)

# %%
fa = np.zeros(26,)
fb = np.zeros(25,)
ga = np.zeros(26,)
gb = np.zeros(25,)

# %%
for i in range(26):
    fa[i],_ = sp.integrate.quad(u,0,2*pi,(i,))
    ga[i],_ = sp.integrate.quad(w,0,2*pi,(i,))
for i in range(25):
    fb[i],_ = sp.integrate.quad(v,0,2*pi,(i+1,))
    gb[i],_ = sp.integrate.quad(z,0,2*pi,(i+1,))

# %%
fa /= pi
fb /= pi
ga /= pi
gb /= pi
fa[0] /= 2
ga[0] /= 2

# %%
# print(fa,fb,ga,gb)

# %%
plt.grid()
plt.plot(np.arange(26),abs(fa),'o',color = 'r')
plt.title('$a_n$ for f(x)')
plt.xlabel('n')
plt.ylabel('$a_n$')
plt.show()

# %%
plt.grid()
plt.plot(np.arange(25),abs(fb),'o',color = 'r')
plt.title('$b_n$ for f(x)')
plt.xlabel('n')
plt.ylabel('$b_n$')
plt.show()

# %%
plt.grid()
plt.plot(abs(ga),'o',color = 'r')
plt.plot(abs(gb),'o',color = 'r')
plt.title('$a_n$ for g(x)')
plt.xlabel('n')
plt.ylabel('$a_n$')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-553c89530ec0> in <module>
#       1 plt.grid()
# ----> 2 plt.plot(abs(ga),abs(gb),'o',color = 'r')
#       3 plt.plot(abs(gb),'o',color = 'r')
#       4 plt.title('$a_n$ for g(x)')
#       5 plt.xlabel('n')
#
# /opt/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# /opt/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1803                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1804                         RuntimeWarning, stacklevel=2)
# -> 1805             return func(ax, *args, **kwargs)
#    1806
#    1807         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /opt/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1601         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1602
# -> 1603         for line in self._get_lines(*args, **kwargs):
#    1604             self.add_line(line)
#    1605             lines.append(line)
#
# /opt/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /opt/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# /opt/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (26,) and (25,)

# %%
plt.grid()
plt.plot(np.arange(25),abs(gb),'o',color = 'r')
plt.title('$b_n$ for g(x)')
plt.xlabel('n')
plt.ylabel('$b_n$')
plt.show()

# %% [markdown]
# As g(x) = cos(cos(x)) is an even function all the odd components of the function is almost equal to zero.

# %%
plt.grid()
plt.loglog(np.arange(25),abs(fb),'o--')
plt.title('$b_n$ for f(x)')
plt.xlabel('n')
plt.ylabel('$b_n$')
plt.show()

# %%
plt.grid()
plt.semilogy(np.arange(26),abs(ga),'o--')
plt.title('$a_n$ for g(x)')
plt.xlabel('n')
plt.ylabel('$a_n$')
plt.show()

# %%
F = [None]*(len(fa)+len(fb))
F[0] = fa[0]
F[1::2] = fa[1:]
F[2::2] = fb
F = np.asarray(F)
# print(F)

# %%
G = [None]*(len(fa)+len(fb))
G[0] = ga[0]
G[1::2] = ga[1:]
G[2::2] = gb
G = np.asarray(G)
# print(G)

# %%
plt.grid()
plt.semilogy(np.arange(26),abs(ga),'o--')
plt.title('Coefficients')
plt.xlabel('n')
plt.ylabel('$a_n$')
plt.show()

# %%
X = np.linspace(0,2*pi,401)
X = X[:-1]
b = f(X)
A = np.zeros((400,51))
A[:,0] = 1
for k in range(1,26):
    A[:,2*k-1] = np.cos(k*X)
    A[:,2*k] = np.sin(k*X)

c1 = np.linalg.lstsq(A,b,rcond = -1)[0]

# %%
plt.grid()
plt.plot(c1,'o',color = 'g')
plt.title('Fourier Coefficients calculated using lstsq method')
plt.xlabel('n')
plt.ylabel('Coefficients')
plt.show()

# %%
X = np.linspace(0,2*pi,401)
X = X[:-1]
b = g(X)
A = np.zeros((400,51))
A[:,0] = 1
for k in range(1,26):
    A[:,2*k-1] = np.cos(k*X)
    A[:,2*k] = np.sin(k*X)

c2 = np.linalg.lstsq(A,b,rcond = -1)[0]

# %%
plt.grid()
plt.plot(c2,'o',color = 'g')
plt.title('Fourier Coefficients calculated using lstsq method')
plt.xlabel('n')
plt.ylabel('Coefficients')
plt.show()

# %%
final_f = A.dot(c1)
plt.grid()
plt.plot(final_f,'-',color = 'g')
plt.plot(f(X),'-.',color = 'b')
plt.title(' Original Function and Reconstructed Function from Fourier Coefficients')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(['original','reconstructed'])
plt.show()

# %%
final_g = A.dot(c2)
plt.grid()
plt.plot(final_g,'-',color = 'g')
plt.plot(g(X),'-.',color = 'b')
plt.title(' Original Function and Reconstructed Function from Fourier Coefficients')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend(['original','reconstructed'])
plt.show()

# %%
# print(c2-G)
